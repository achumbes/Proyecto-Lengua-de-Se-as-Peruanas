# %% [markdown]
# <a href="https://colab.research.google.com/github/achumbes/Proyecto-Lengua-de-Se-as-Peruanas/blob/main/Google%20Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
#!unzip '/content/drive/My Drive/TF2_EfficientDet_D1_640x640/object_detection.zip' -d '/content/drive/My Drive/TF2_EfficientDet_D1_640x640'

# %%
# !pip install tf-models-official
# !pip install tf_slim
# !pip install lvis
# !pip install tensorflow_io

# %%
# %cd '/content/drive/My Drive/TF2_EfficientDet_D1_640x640/object_detection'
# Out:
# /content/drive/My Drive/TF2_EfficientDet_D1_640x640/object_detection

# %%
# !python model_main_tf2.py --pipeline_config_path=training/ssd_efficientdet_d1_640x640_coco17_tpu-8.config --model_dir=training –alsologtostderr
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  'Loss/localization_loss': 0.17516206,
#  'Loss/regularization_loss': 0.047114417,
#  'Loss/total_loss': 0.77225894,
#  'learning_rate': 0.07999355}
# INFO:tensorflow:Step 4300 per-step time 0.439s
# I1119 02:23:58.888749 140057002383232 model_lib_v2.py:707] Step 4300 per-step time 0.439s
# INFO:tensorflow:{'Loss/classification_loss': 0.36402345,
#  'Loss/localization_loss': 0.076518096,
#  'Loss/regularization_loss': 0.047505807,
#  'Loss/total_loss': 0.48804733,
#  'learning_rate': 0.07999277}
# I1119 02:23:58.889134 140057002383232 model_lib_v2.py:708] {'Loss/classification_loss': 0.36402345,
#  'Loss/localization_loss': 0.076518096,
#  'Loss/regularization_loss': 0.047505807,
#  'Loss/total_loss': 0.48804733,
#  'learning_rate': 0.07999277}
# INFO:tensorflow:Step 4400 per-step time 0.441s
# I1119 02:24:42.992607 140057002383232 model_lib_v2.py:707] Step 4400 per-step time 0.441s
# ...

# %%
# !python exporter_main_v2.py --trained_checkpoint_dir=training --pipeline_config_path=training/ssd_efficientdet_d1_640x640_coco17_tpu-8.config --output_directory inference_graph
# Out:
# 2022-11-19 07:31:03.938310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-19 07:31:04.139478: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-19 07:31:05.052212: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...
